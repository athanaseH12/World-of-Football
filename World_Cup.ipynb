# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
WC =pd.read_csv("WorldCups.csv")

# %%
WC
# Out:
#     Year       Country      Winner      Runners-Up        Third  \
# 0   1930       Uruguay     Uruguay       Argentina          USA
# 1   1934         Italy       Italy  Czechoslovakia      Germany
# 2   1938        France       Italy         Hungary       Brazil
# 3   1950        Brazil     Uruguay          Brazil       Sweden
# 4   1954   Switzerland  Germany FR         Hungary      Austria
# 5   1958        Sweden      Brazil          Sweden       France
# 6   1962         Chile      Brazil  Czechoslovakia        Chile
# 7   1966       England     England      Germany FR     Portugal
# 8   1970        Mexico      Brazil           Italy   Germany FR
# 9   1974       Germany  Germany FR     Netherlands       Poland
# 10  1978     Argentina   Argentina     Netherlands       Brazil
# 11  1982         Spain       Italy      Germany FR       Poland
# 12  1986        Mexico   Argentina      Germany FR       France
# 13  1990         Italy  Germany FR       Argentina        Italy
# ...

# %%
plt.figure(figsize=(12,6))
sns.set_style("whitegrid")
AT =sns.scatterplot(data=WC,x="Year",y="Country")
plt.tick_params(axis="x",labelrotation=27)
AT.set_xticks(np.arange(1930,2018,4));

# %%
WC.groupby(["Year", "Winner"]).sum()
# Out:
#                       Country      Runners-Up        Third          Fourth  \
# Year Winner
# 1930 Uruguay          Uruguay       Argentina          USA      Yugoslavia
# 1934 Italy              Italy  Czechoslovakia      Germany         Austria
# 1938 Italy             France         Hungary       Brazil          Sweden
# 1950 Uruguay           Brazil          Brazil       Sweden           Spain
# 1954 Germany FR   Switzerland         Hungary      Austria         Uruguay
# 1958 Brazil            Sweden          Sweden       France      Germany FR
# 1962 Brazil             Chile  Czechoslovakia        Chile      Yugoslavia
# 1966 England          England      Germany FR     Portugal    Soviet Union
# 1970 Brazil            Mexico           Italy   Germany FR         Uruguay
# 1974 Germany FR       Germany     Netherlands       Poland          Brazil
# 1978 Argentina      Argentina     Netherlands       Brazil           Italy
# ...

# %%
WC.groupby(["Winner"]).size()
# Out:
# Winner
# Argentina     2
# Brazil        5
# England       1
# France        1
# Germany       1
# Germany FR    3
# Italy         4
# Spain         1
# Uruguay       2
# dtype: int64

# %%
WC.groupby(["Year", "Attendance"]).sum()
# Out:
#                       Country      Winner      Runners-Up        Third  \
# Year Attendance
# 1930 590.549          Uruguay     Uruguay       Argentina          USA
# 1934 363.000            Italy       Italy  Czechoslovakia      Germany
# 1938 375.700           France       Italy         Hungary       Brazil
# 1950 1.045.246         Brazil     Uruguay          Brazil       Sweden
# 1954 768.607      Switzerland  Germany FR         Hungary      Austria
# 1958 819.810           Sweden      Brazil          Sweden       France
# 1962 893.172            Chile      Brazil  Czechoslovakia        Chile
# 1966 1.563.135        England     England      Germany FR     Portugal
# 1970 1.603.975         Mexico      Brazil           Italy   Germany FR
# 1974 1.865.753        Germany  Germany FR     Netherlands       Poland
# 1978 1.545.791      Argentina   Argentina     Netherlands       Brazil
# 1982 2.109.723          Spain       Italy      Germany FR       Poland
# ...

# %%
plt.figure(figsize=(12,6))
S=plt.scatter(WC["Year"], WC["Attendance"])
S1 =plt.plot(WC["Year"] ,WC["Attendance"])
plt.xticks(np.arange(1930,2018,4));

# %%
plt.figure(figsize=(12,4))
D =plt.bar(WC["Year"],WC["Attendance"])
plt.xticks(np.arange(1930,2018,4));
